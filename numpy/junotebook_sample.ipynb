# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.arange(0, 100, 1)
plt.title(r'$\alpha > \beta$', color='r')
plt.text(0, 80, r'$\sum_{i=0}\infty x_i$',color='g')

plt.plot(a)
plt.show()
